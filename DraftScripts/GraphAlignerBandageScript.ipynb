# %% [markdown]
# # This script is used to read and compare the results from Bandage and GraphAligner
# ## Written by Yusreen Shah
# ## Date: May 8th 2023

# %%
#Import the libraries
import numpy as np
import pandas as pd
import re

# %%
#Create a dataframe for Bandage Combined1
Bandage_Combined1= pd.read_csv('111_Graph/BandageOutcombinedOutput.tsv', sep='\t')

# %%
#Create a dataframe for GraphAligner Combined1
GraphAligner_Combined1=pd.read_csv('111_Graph/GraphAlignerOutputCombined1tsv.tsv', sep='\t', names=["Query", "Query Length", "Query Start", 
                                          "Query End","Strand Relative Length","Path Matching","Path Length",
                                         "Start Position on Path","End Position on Path","Number of residues Matches",
                                         "Alignment Back Length","Mapping Quality","Column 1"])

# %%
GraphAligner_Combined1
# Out:
#                                                  Query  Query Length
# 0    gb|U59183|+|247-859|ARO:3002581|AAC(6')-Ib10 [...           612  \
# 1    gb|U59183|+|247-859|ARO:3002581|AAC(6')-Ib10 [...           612
# 2    gb|AY136758|+|377-947|ARO:3002582|AAC(6')-Ib11...           570
# 3    gb|FJ854362|+|1702-2257|ARO:3002576|AAC(6')-Ib...           555
# 4    gb|AF445082|+|2788-3343|ARO:3002577|AAC(6')-Ib...           555
# ..                                                 ...           ...
# 375  gb|AJ318094|+|0-861|ARO:3000961|TEM-94 [Escher...           861
# 376  gb|AJ308558|+|181-1042|ARO:3000962|TEM-95 [Esc...           861
# 377  gb|AY092401|+|0-861|ARO:3000963|TEM-96 [Escher...           861
# 378  gb|AM990992.1|-|1001760-1003680|ARO:3000186|te...          1920
# 379  gb|U00096|-|2098446-2099613|ARO:3003577|ugd [E...          1167
#
#      Query Start  Query End Strand Relative Length Path Matching  Path Length
# 0             25        612                      +         >7593         2524  \
# 1              2         18                      +         <1851        79238
# 2             20        570                      +         >7593         2524
# 3              0        555                      +         >7593         2524
# 4              0        555                      +         >7593         2524
# ..           ...        ...                    ...           ...          ...
# 375            0        861                      +         >5967         1044
# 376            0        861                      +         >5967         1044
# 377            0        861                      +         >5967         1044
# 378            0       1920                      +         <1107        47514
# 379            0       1167                      +         <3493        11214
#
#      Start Position on Path  End Position on Path  Number of residues Matches
# 0                        55                   642                         586  \
# 1                     37281                 37296                          15
# 2                        92                   642                         547
# 3                        87                   642                         553
# 4                        87                   642                         553
# ..                      ...                   ...                         ...
# 375                      36                   897                         852
# 376                      36                   897                         859
# 377                      36                   897                         858
# 378                   33707                 35627                        1874
# 379                    1619                  2786                        1136
#
#      Alignment Back Length  Mapping Quality Column 1
# 0                      587              255   NM:i:1
# 1                       16              255   NM:i:1
# 2                      550              255   NM:i:3
# 3                      555              255   NM:i:2
# 4                      555              255   NM:i:2
# ..                     ...              ...      ...
# 375                    861              255   NM:i:9
# 376                    861              255   NM:i:2
# 377                    861              255   NM:i:3
# 378                   1920              255  NM:i:46
# 379                   1167              255  NM:i:31
#
# [380 rows x 13 columns]

# %% [markdown]
# ## This section cleans the data from GraphAligner so that the columns can be compared easily.

# %%
#Format the Query column from  GraphAligner_Combined1 so that the Query column is the same as the one from Bandage
pattern = r'\[.*?\]'
def format_query(x):
    return re.sub(pattern,"", x).rstrip()
    


GraphAligner_Combined1['Query'] = GraphAligner_Combined1['Query'].map(format_query)

# %%
# Add Braces to the values that now have ','
def remove_angle(value):
    if '>' or '<' in value:
        return value
    else:
        return value

# %%
#Remove > and < from the path
GraphAligner_Combined1['Path Matching_Bandage'] = GraphAligner_Combined1['Path Matching']
GraphAligner_Combined1
GraphAligner_Combined1['Path Matching_Bandage']=GraphAligner_Combined1['Path Matching_Bandage'].str.replace('<', "")
GraphAligner_Combined1['Path Matching_Bandage']=GraphAligner_Combined1['Path Matching_Bandage'].str.replace('>', "")

# %%
#GraphAligner_Combined1['Path Matching_2'] = GraphAligner_Combined1['Path Matching'].str.replace('>', "")
GraphAligner_Combined1
# Out:
#                                                 Query  Query Length
# 0        gb|U59183|+|247-859|ARO:3002581|AAC(6')-Ib10           612  \
# 1        gb|U59183|+|247-859|ARO:3002581|AAC(6')-Ib10           612
# 2      gb|AY136758|+|377-947|ARO:3002582|AAC(6')-Ib11           570
# 3     gb|FJ854362|+|1702-2257|ARO:3002576|AAC(6')-Ib3           555
# 4     gb|AF445082|+|2788-3343|ARO:3002577|AAC(6')-Ib4           555
# ..                                                ...           ...
# 375            gb|AJ318094|+|0-861|ARO:3000961|TEM-94           861
# 376         gb|AJ308558|+|181-1042|ARO:3000962|TEM-95           861
# 377            gb|AY092401|+|0-861|ARO:3000963|TEM-96           861
# 378  gb|AM990992.1|-|1001760-1003680|ARO:3000186|tetM          1920
# 379       gb|U00096|-|2098446-2099613|ARO:3003577|ugd          1167
#
#      Query Start  Query End Strand Relative Length Path Matching  Path Length
# 0             25        612                      +         >7593         2524  \
# 1              2         18                      +         <1851        79238
# 2             20        570                      +         >7593         2524
# 3              0        555                      +         >7593         2524
# 4              0        555                      +         >7593         2524
# ..           ...        ...                    ...           ...          ...
# 375            0        861                      +         >5967         1044
# 376            0        861                      +         >5967         1044
# 377            0        861                      +         >5967         1044
# 378            0       1920                      +         <1107        47514
# 379            0       1167                      +         <3493        11214
#
#      Start Position on Path  End Position on Path  Number of residues Matches
# 0                        55                   642                         586  \
# 1                     37281                 37296                          15
# 2                        92                   642                         547
# 3                        87                   642                         553
# 4                        87                   642                         553
# ..                      ...                   ...                         ...
# 375                      36                   897                         852
# 376                      36                   897                         859
# 377                      36                   897                         858
# 378                   33707                 35627                        1874
# 379                    1619                  2786                        1136
#
#      Alignment Back Length  Mapping Quality Column 1 Path Matching_Bandage
# 0                      587              255   NM:i:1                  7593
# 1                       16              255   NM:i:1                  1851
# 2                      550              255   NM:i:3                  7593
# 3                      555              255   NM:i:2                  7593
# 4                      555              255   NM:i:2                  7593
# ..                     ...              ...      ...                   ...
# 375                    861              255   NM:i:9                  5967
# 376                    861              255   NM:i:2                  5967
# 377                    861              255   NM:i:3                  5967
# 378                   1920              255  NM:i:46                  1107
# 379                   1167              255  NM:i:31                  3493
#
# [380 rows x 14 columns]

# %%
GraphAligner_Combined1.to_csv("test_Grap_2.tsv",sep='\t')

# %%
#Chnaging the types
GraphAligner_Combined1.dtypes
# Out:
# Query                         object
# Query Length                   int64
# Query Start                    int64
# Query End                      int64
# Strand Relative Length        object
# Path Matching                 object
# Path Length                    int64
# Start Position on Path         int64
# End Position on Path           int64
# Number of residues Matches     int64
# Alignment Back Length          int64
# Mapping Quality                int64
# Column 1                      object
# Path Matching_Bandage         object
# dtype: object

# %%
GraphAligner_Combined1.to_csv("TestCombined.tsv",sep='\t')

# %%
GraphAligner_Combined1["Alignment Back Length"]=GraphAligner_Combined1["Alignment Back Length"].astype(int)

# %% [markdown]
# ## This section drops the  rows with coverages < 50 from GraphAligner_Combined1

# %%
# Calculate the coverage for GraphAligner
GraphAligner_Combined1["Coverage"]=GraphAligner_Combined1["Alignment Back Length"]/GraphAligner_Combined1["Query Length"]*100

# %%
#Drop the coverages that are < 50 from GraphAligner 
GraphAligner_Combined1.drop(GraphAligner_Combined1[GraphAligner_Combined1['Coverage'] < 50].index, inplace = True)
GraphAligner_Combined1
GraphAligner_Combined1.to_csv("Test_com.tsv", sep='\t')

# %% [markdown]
# ## This section cleans the data from Bandage so that the  formatting of the path column is the same as the one in Graphaligner.

# %%
pattern1 = r'\(.*?\)'
def format_path(x):
    return re.sub(pattern1,"", x).rstrip()

# %%
Bandage_Combined1['Path']=Bandage_Combined1['Path'].map(format_path)

# %%
Bandage_Combined1['Path']=Bandage_Combined1['Path'].str.replace('+', "")
Bandage_Combined1['Path']=Bandage_Combined1['Path'].str.replace('-', "")

# %% [markdown]
# ## This section creates 2 dataframes so that it is easier to compare. The Query and Resulting path are kept.
# ### GraphAligner_Combined_Query_Path
# ### Bandage_Combined_Query_Path

# %%
GraphAligner_Combined_Query_Path=GraphAligner_Combined1[['Query','Start Position on Path','End Position on Path','Path Matching','Path Matching_Bandage']]

# %%
Bandage_Combined_Query_Path=Bandage_Combined1[['Query','Path']]

# %%
#Sort the values alphabetically.
Bandage_Combined_Query_Path=Bandage_Combined_Query_Path.sort_values(by=['Query']).reset_index()

# %%
GraphAligner_Combined_Query_Path=GraphAligner_Combined_Query_Path.sort_values(by=['Query']).reset_index()

# %% [markdown]
# ## This section creates df_union. The dataframe stores the Query and path from both software.

# %%
#Use merge operation so that we have the sequences for both softwares for successful queries
df=pd.merge(Bandage_Combined_Query_Path,GraphAligner_Combined_Query_Path, on='Query')
#union
#df_union=pd.concat([Bandage_Combined_Query_Path,GraphAligner_Combined_Query_Path], axis=1)
df_union=pd.merge(Bandage_Combined_Query_Path,GraphAligner_Combined_Query_Path, on='Query',how="outer")

# %%
df_union
# Out:
#      index_x                                              Query   Path
# 0      145.0             gb|AB023477|+|0-861|ARO:3001082|SHV-24   5151  \
# 1      385.0             gb|AB049569|+|0-861|ARO:3000958|TEM-91   5967
# 2      182.0             gb|AB302939|+|8-869|ARO:3001115|SHV-60   5151
# 3       77.0            gb|AB372881|+|8-869|ARO:3001160|SHV-111   5151
# 4       91.0           gb|AB551737|+|14-875|ARO:3001177|SHV-133   5151
# ..       ...                                                ...    ...
# 395      NaN    gb|AY130284|+|0-785|ARO:3000941|TEM-75  Partial    NaN
# 396      NaN   gb|AY130285|+|0-785|ARO:3000981|TEM-118  Partial    NaN
# 397      NaN    gb|AY590467|+|0-729|ARO:3001110|SHV-53  Partial    NaN
# 398      NaN   gb|JX050178|+|0-853|ARO:3001058|TEM-199  Partial    NaN
# 399      NaN  gb|NG_050218.1|+|0-1061|ARO:3001044|TEM-181  P...    NaN
#
#      index_y  Start Position on Path  End Position on Path Path Matching
# 0      132.0                    23.0                 884.0         <5151  \
# 1      372.0                    36.0                 897.0         >5967
# 2      169.0                    23.0                 884.0         <5151
# 3       64.0                    23.0                 884.0         <5151
# 4       78.0                    23.0                 884.0         <5151
# ..       ...                     ...                   ...           ...
# 395    355.0                    72.0                 857.0         >5967
# 396    228.0                    72.0                 857.0         >5967
# 397    163.0                    43.0                 772.0         <5151
# 398    303.0                    44.0                 897.0         >5967
# 399    285.0                   366.0                1419.0    >5965>5967
#
#     Path Matching_Bandage
# 0                    5151
# 1                    5967
# 2                    5151
# 3                    5151
# 4                    5151
# ..                    ...
# 395                  5967
# 396                  5967
# 397                  5151
# 398                  5967
# 399              59655967
#
# [400 rows x 8 columns]

# %%
df_union.rename(columns = {'Path':'Path_Bandage'}, inplace = True)
df_union.rename(columns = {'Path Matching_Bandage':'Path_GraphAligner'}, inplace = True)

# %%
df_union['Path_Bandage'] = df_union['Path_Bandage'].str.replace(',',"").str.strip()
df_union['Path_GraphAligner'] = df_union['Path_GraphAligner'].str.strip()

# %%
df_union['Path_Bandage'] = df_union['Path_Bandage'].str.findall(r'[^\s,]+').str.join('')

# %% [markdown]
# ## This section compares the  resulting paths for each query

# %%
#Check for similar path for the queries
df_union['Equal'] = np.where(df_union['Path_Bandage']==df_union['Path_GraphAligner'], 
                                           'yes', 'no')

# %%
df_union
# Out:
#      index_x                                              Query Path_Bandage
# 0      145.0             gb|AB023477|+|0-861|ARO:3001082|SHV-24         5151  \
# 1      385.0             gb|AB049569|+|0-861|ARO:3000958|TEM-91         5967
# 2      182.0             gb|AB302939|+|8-869|ARO:3001115|SHV-60         5151
# 3       77.0            gb|AB372881|+|8-869|ARO:3001160|SHV-111         5151
# 4       91.0           gb|AB551737|+|14-875|ARO:3001177|SHV-133         5151
# ..       ...                                                ...          ...
# 395      NaN    gb|AY130284|+|0-785|ARO:3000941|TEM-75  Partial          NaN
# 396      NaN   gb|AY130285|+|0-785|ARO:3000981|TEM-118  Partial          NaN
# 397      NaN    gb|AY590467|+|0-729|ARO:3001110|SHV-53  Partial          NaN
# 398      NaN   gb|JX050178|+|0-853|ARO:3001058|TEM-199  Partial          NaN
# 399      NaN  gb|NG_050218.1|+|0-1061|ARO:3001044|TEM-181  P...          NaN
#
#      index_y  Start Position on Path  End Position on Path Path Matching
# 0      132.0                    23.0                 884.0         <5151  \
# 1      372.0                    36.0                 897.0         >5967
# 2      169.0                    23.0                 884.0         <5151
# 3       64.0                    23.0                 884.0         <5151
# 4       78.0                    23.0                 884.0         <5151
# ..       ...                     ...                   ...           ...
# 395    355.0                    72.0                 857.0         >5967
# 396    228.0                    72.0                 857.0         >5967
# 397    163.0                    43.0                 772.0         <5151
# 398    303.0                    44.0                 897.0         >5967
# 399    285.0                   366.0                1419.0    >5965>5967
#
#     Path_GraphAligner Equal
# 0                5151   yes
# 1                5967   yes
# 2                5151   yes
# 3                5151   yes
# 4                5151   yes
# ..                ...   ...
# 395              5967    no
# 396              5967    no
# 397              5151    no
# 398              5967    no
# 399          59655967    no
#
# [400 rows x 9 columns]

# %% [markdown]
# ### Print the yes if path is identical, and no if path is different

# %%
df_union['Equal'].value_counts()
# Out:
# Equal
# yes    371
# no      29
# Name: count, dtype: int64

# %%
# Create a new dataframe to store the extracted rows
df_path_notEqual = df_union[df_union['Equal'] == 'no'].copy().reset_index()

# Print the new dataframe
df_path_notEqual
# Out:
#     index  index_x                                              Query
# 0      10     30.0          gb|AF047479|+|1295-2087|ARO:3002603|aadA3  \
# 1      27     28.0          gb|AF156486|+|5012-5792|ARO:3002602|aadA2
# 2      59    372.0            gb|AF527798.1|+|0-785|ARO:3000879|TEM-7
# 3      66     36.0       gb|AF550679.1|-|80976-81768|ARO:3002601|aadA
# 4      81     22.0           gb|AJ809407|+|118-898|ARO:3002620|aadA23
# 5      88     32.0       gb|AM040708.1|+|1173-1965|ARO:3004704|aadA8b
# 6     108     20.0            gb|AM261837|+|73-865|ARO:3002619|aadA22
# 7     132    240.0            gb|AY130282|+|0-764|ARO:3000980|TEM-117
# 8     133    368.0             gb|AY130284|+|0-785|ARO:3000941|TEM-75
# 9     134    241.0            gb|AY130285|+|0-785|ARO:3000981|TEM-118
# 10    137     34.0            gb|AY139603|+|106-898|ARO:3002608|aadA8
# 11    139     18.0            gb|AY171244|+|46-838|ARO:3002618|aadA21
# 12    162    176.0             gb|AY590467|+|0-729|ARO:3001110|SHV-53
# 13    174     41.0  gb|BX664015.1|-|103017-103833|ARO:3002641|APH(...
# 14    177     26.0     gb|CP003022|+|336788-337580|ARO:3003197|aadA25
# 15    198     14.0         gb|DQ393783|+|1799-2591|ARO:3002615|aadA15
# 16    200     24.0             gb|DQ677333|+|0-780|ARO:3002621|aadA24
# 17    230     11.0            gb|FJ381668|+|56-848|ARO:3002612|aadA12
# 18    232     16.0         gb|FJ460181|+|1790-2582|ARO:3002617|aadA17
# 19    245     63.0   gb|FO834906.1|-|2173974-2175099|ARO:3005044|OmpA
# 20    295    316.0            gb|JX050178|+|0-853|ARO:3001058|TEM-199
# 21    353    298.0        gb|NG_050218.1|+|0-1061|ARO:3001044|TEM-181
# 22    393      NaN   gb|AF527798.1|+|0-785|ARO:3000879|TEM-7  Partial
# 23    394      NaN   gb|AY130282|+|0-764|ARO:3000980|TEM-117  Partial
# 24    395      NaN    gb|AY130284|+|0-785|ARO:3000941|TEM-75  Partial
# 25    396      NaN   gb|AY130285|+|0-785|ARO:3000981|TEM-118  Partial
# 26    397      NaN    gb|AY590467|+|0-729|ARO:3001110|SHV-53  Partial
# 27    398      NaN   gb|JX050178|+|0-853|ARO:3001058|TEM-199  Partial
# 28    399      NaN  gb|NG_050218.1|+|0-1061|ARO:3001044|TEM-181  P...
#
#    Path_Bandage  index_y  Start Position on Path  End Position on Path
# 0          7593     22.0                  1687.0                2477.0  \
# 1          7593     21.0                  1699.0                2479.0
# 2          5967      NaN                     NaN                   NaN
# 3          7591     25.0                   711.0                1500.0
# 4          7591     18.0                   731.0                1500.0
# 5          7593     23.0                  1687.0                2477.0
# 6          7591     17.0                   711.0                1500.0
# 7          5967      NaN                     NaN                   NaN
# 8          5967      NaN                     NaN                   NaN
# 9          5967      NaN                     NaN                   NaN
# 10         7593     24.0                  1687.0                2477.0
# 11         7591     16.0                   711.0                1500.0
# 12         5151      NaN                     NaN                   NaN
# 13    264523479     29.0                    75.0                 891.0
# 14         7593     20.0                  1687.0                2477.0
# 15         7591     14.0                   711.0                1498.0
# 16         7591     19.0                   731.0                1500.0
# 17         7591     13.0                   711.0                1498.0
# 18         7593     15.0                  1687.0                2479.0
# 19         2851     50.0                  9172.0               10297.0
# 20         5967      NaN                     NaN                   NaN
# 21     59655967      NaN                     NaN                   NaN
# 22          NaN    359.0                    72.0                 857.0
# 23          NaN    227.0                    72.0                 836.0
# 24          NaN    355.0                    72.0                 857.0
# 25          NaN    228.0                    72.0                 857.0
# 26          NaN    163.0                    43.0                 772.0
# 27          NaN    303.0                    44.0                 897.0
# 28          NaN    285.0                   366.0                1419.0
#
#    Path Matching Path_GraphAligner Equal
# 0          >7591              7591    no
# 1          >7591              7591    no
# 2            NaN               NaN    no
# 3          >7593              7593    no
# 4          >7593              7593    no
# 5          >7591              7591    no
# 6          >7593              7593    no
# 7            NaN               NaN    no
# 8            NaN               NaN    no
# 9            NaN               NaN    no
# 10         >7591              7591    no
# 11         >7593              7593    no
# 12           NaN               NaN    no
# 13   <2645<22251         264522251    no
# 14         >7591              7591    no
# 15         >7593              7593    no
# 16         >7593              7593    no
# 17         >7593              7593    no
# 18         >7591              7591    no
# 19         <2227              2227    no
# 20           NaN               NaN    no
# 21           NaN               NaN    no
# 22         >5967              5967    no
# 23         >5967              5967    no
# 24         >5967              5967    no
# 25         >5967              5967    no
# 26         <5151              5151    no
# 27         >5967              5967    no
# 28    >5965>5967          59655967    no

# %%
#Drop the rows where Path_GraphAligner= NaN
df_path_notEqual.dropna(subset=['Path_GraphAligner'], inplace=True)
df_path_notEqual.reset_index()
df_path_notEqual.drop(['index','index_x','index_y'],axis=1,inplace=True)

# %%
df_path_notEqual['Start Position on Path']=df_path_notEqual['Start Position on Path'].astype(int)
df_path_notEqual['End Position on Path']=df_path_notEqual['End Position on Path'].astype(int)
df_path_notEqual
# Out:
#                                                 Query Path_Bandage
# 0           gb|AF047479|+|1295-2087|ARO:3002603|aadA3         7593  \
# 1           gb|AF156486|+|5012-5792|ARO:3002602|aadA2         7593
# 3        gb|AF550679.1|-|80976-81768|ARO:3002601|aadA         7591
# 4            gb|AJ809407|+|118-898|ARO:3002620|aadA23         7591
# 5        gb|AM040708.1|+|1173-1965|ARO:3004704|aadA8b         7593
# 6             gb|AM261837|+|73-865|ARO:3002619|aadA22         7591
# 10            gb|AY139603|+|106-898|ARO:3002608|aadA8         7593
# 11            gb|AY171244|+|46-838|ARO:3002618|aadA21         7591
# 13  gb|BX664015.1|-|103017-103833|ARO:3002641|APH(...    264523479
# 14     gb|CP003022|+|336788-337580|ARO:3003197|aadA25         7593
# 15         gb|DQ393783|+|1799-2591|ARO:3002615|aadA15         7591
# 16             gb|DQ677333|+|0-780|ARO:3002621|aadA24         7591
# 17            gb|FJ381668|+|56-848|ARO:3002612|aadA12         7591
# 18         gb|FJ460181|+|1790-2582|ARO:3002617|aadA17         7593
# 19   gb|FO834906.1|-|2173974-2175099|ARO:3005044|OmpA         2851
# 22   gb|AF527798.1|+|0-785|ARO:3000879|TEM-7  Partial          NaN
# 23   gb|AY130282|+|0-764|ARO:3000980|TEM-117  Partial          NaN
# 24    gb|AY130284|+|0-785|ARO:3000941|TEM-75  Partial          NaN
# 25   gb|AY130285|+|0-785|ARO:3000981|TEM-118  Partial          NaN
# 26    gb|AY590467|+|0-729|ARO:3001110|SHV-53  Partial          NaN
# 27   gb|JX050178|+|0-853|ARO:3001058|TEM-199  Partial          NaN
# 28  gb|NG_050218.1|+|0-1061|ARO:3001044|TEM-181  P...          NaN
#
#     Start Position on Path  End Position on Path Path Matching
# 0                     1687                  2477         >7591  \
# 1                     1699                  2479         >7591
# 3                      711                  1500         >7593
# 4                      731                  1500         >7593
# 5                     1687                  2477         >7591
# 6                      711                  1500         >7593
# 10                    1687                  2477         >7591
# 11                     711                  1500         >7593
# 13                      75                   891   <2645<22251
# 14                    1687                  2477         >7591
# 15                     711                  1498         >7593
# 16                     731                  1500         >7593
# 17                     711                  1498         >7593
# 18                    1687                  2479         >7591
# 19                    9172                 10297         <2227
# 22                      72                   857         >5967
# 23                      72                   836         >5967
# 24                      72                   857         >5967
# 25                      72                   857         >5967
# 26                      43                   772         <5151
# 27                      44                   897         >5967
# 28                     366                  1419    >5965>5967
#
#    Path_GraphAligner Equal
# 0               7591    no
# 1               7591    no
# 3               7593    no
# 4               7593    no
# 5               7591    no
# 6               7593    no
# 10              7591    no
# 11              7593    no
# 13         264522251    no
# 14              7591    no
# 15              7593    no
# 16              7593    no
# 17              7593    no
# 18              7591    no
# 19              2227    no
# 22              5967    no
# 23              5967    no
# 24              5967    no
# 25              5967    no
# 26              5151    no
# 27              5967    no
# 28          59655967    no

# %%
df_path_notEqual.to_csv("GraphAlignerNotEqual.tsv",sep='\t')

# %% [markdown]
# ## This section checks the queries that do not have any path in Bandage.

# %%
#Get the queries that are found by Bandage only
Bandage_Combined_Query_Path_Compare= Bandage_Combined_Query_Path.drop(['index'], axis=1)
Bandage_Combined_Query_Path_Compare

# %%
#Check for similar path for the queries
df_union['Query_Not_Bandage'] = np.where(df_union['Path_Bandage'].isna(), 
                                           'yes', 'no')

# %%
df_union

# %%
df_union['Query_Not_Bandage'].value_counts()

# %% [markdown]
# ## This section checks the queries that do not have any path in GraphAligner.

# %%
#Check for similar path for the queries
df_union['Query_Not_GraphAligner'] = np.where(df_union['Path_GraphAligner'].isna(), 
                                           'yes', 'no')

# %%
df_union['Query_Not_GraphAligner'].value_counts()

# %%
rslt_df_Bandage = df_union[df_union['Query_Not_Bandage']=='yes']

# %% [markdown]
# ### Print the Queries that are missed by Bandage

# %%
rslt_df_Bandage

# %% [markdown]
# ### Print the Queries that are missed by GraphAligner

# %%
rslt_df_GraphAligner = df_union[df_union['Query_Not_GraphAligner']=='yes']

# %%
rslt_df_GraphAligner

# %%
#Save the queries missed by GraphAligner in a .tsv file
rslt_df_GraphAligner.to_csv("GraphAlignerMissedQueries.tsv",sep='\t')
